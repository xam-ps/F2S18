# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
# !ls
# Out:
# Basic Plot.ipynb data             notes.txt        prelim.ipynb

# %%
df_agg1 = pd.read_csv("data/vin=VF1RFA00257138714.csv")
df_agg2 = pd.read_csv("data/vin=VF1RFA00357138740.csv")

df_agg1['datetime'] = pd.to_datetime(df_agg1['timestamp'], unit='s')
df_agg2['datetime'] = pd.to_datetime(df_agg2['timestamp'], unit='s')

# %%
print("Difference in Percent, Car 2 Baseline")
round(100*(df_agg2.describe()-df_agg1.describe())/df_agg2.describe(),2)
# Out:
# Difference in Percent, Car 2 Baseline
#        Ambiant_Pressure  Canister_Controler  Current_for_Injector_Opening  \
# count             73.79               73.79                         57.25
# mean              -0.77                6.08                          1.15
# std               -5.41                6.20                          1.22
# min                4.92               -0.17                        -11.55
# 25%               -1.17               -5.32                          1.22
# 50%               -0.65                7.62                          2.10
# 75%               -0.38               12.52                          0.50
# max                0.77                0.00                          0.01
#
#        Distance_Km  Lambda_Adapation  Gear_Engaged  Lambda_Control_1  \
# count        73.79             84.18         73.79         73.790000
# mean         10.43           -133.73          2.83        -31.340000
# ...

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
layout=go.Layout(title="Scatter Plot", xaxis={'title':'x1'}, yaxis={'title':'x2'})
trace1=go.Scatter(x=df_agg2.datetime, y=df_agg2.Engine_Oil_Temperature, mode = 'markers')
data=go.Data([trace1])
figure=go.Figure(data=data,layout=layout)

                      
plot(figure)
# Out:
# /anaconda3/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# 'file:///Users/ruhullahshah/Desktop/continental-hackathon-predective-maintenance/temp-plot.html'

# %%
df_agg2['datetime'] = pd.to_datetime(df_agg2['timestamp'], unit='s')
df_agg2.head()
# Out:
#       Vehicle_Number  Ambiant_Pressure  Canister_Controler  \
# 0  VF1RFA00357138740        980.774720            8.806135
# 1  VF1RFA00357138740        963.088938            7.982265
# 2  VF1RFA00357138740        970.696425           84.499417
# 3  VF1RFA00357138740        910.430810           43.313104
# 4  VF1RFA00357138740        985.873937           23.192817
#
#    Current_for_Injector_Opening  Distance_Km  Lambda_Adapation  Gear_Engaged  \
# 0                     15.596389        20710         -0.682068      5.921257
# 1                     14.641683        18448          0.878906      6.000000
# 2                     12.106834        18898         -0.881958      6.000000
# 3                     15.822132        21271          1.069641      6.000000
# 4                           NaN        11544          3.022766      5.000000
#
#    Lambda_Control_1  Lambda_Control_2  MAF_Before_Compressor  Engine_MAF  \
# ...
